# %%
# importing libraries

import pandas as pd
from sodapy import Socrata

# %%
# Extracting the data 
client = Socrata("mydata.iowa.gov", None)
top_brands = client.get("m3tr-qhgy",select="Volume_Sold__Gallons",where ="date > '2019-07-01T00:00:00'",limit =202174 )
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-46-b9f3fa2806bc> in <module>
#       1 # Extracting the data
#       2 client = Socrata("mydata.iowa.gov", None)
# ----> 3 top_brands = client.get("m3tr-qhgy",select="Volume_Sold__Gallons",where ="date > '2019-07-01T00:00:00'",limit =202174 )
#
# ~\Anaconda3\lib\site-packages\sodapy\__init__.py in get(self, dataset_identifier, content_type, **kwargs)
#     360
#     361         response = self._perform_request("get", resource, headers=headers,
# --> 362                                          params=params)
#     363         return response
#     364
#
# ~\Anaconda3\lib\site-packages\sodapy\__init__.py in _perform_request(self, request_type, resource, **kwargs)
#     475         # handle errors
#     476         if response.status_code not in (200, 202):
# --> 477             _raise_for_status(response)
#     478
#     479         # when responses have no content body (ie. delete, set_permission),
#
# ~\Anaconda3\lib\site-packages\sodapy\__init__.py in _raise_for_status(response)
#     529         if more_info and more_info.lower() != response.reason.lower():
#     530             http_error_msg += ".\n\t{0}".format(more_info)
# --> 531         raise requests.exceptions.HTTPError(http_error_msg, response=response)
#     532
#     533
#
# HTTPError: 400 Client Error: Bad Request.
# 	Invalid SoQL query

# %%
results = client.get("m3tr-qhgy",select="Count(*)",where ="date > '2019-07-01T00:00:00' ")

# %%
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(top_brands)

# %%
results
# Out:
# [{'Count': '202174'}]

# %%
 16707545

# %%
top_brands
# Out:
# [{'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Blended Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Flavored Rum',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Scotch Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Straight Bourbon Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Spiced Rum',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Irish Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Imported Brandies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Imported Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Neutral Grain Spirits',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mezcal',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Neutral Grain Spirits Flavored',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Scotch Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Spiced Rum',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Scotch Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Scotch Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mezcal',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Scotch Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Neutral Grain Spirits',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Canadian Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Imported Distilled Spirit Specialty',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Temporary & Specialty Packages',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
# ...
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Scotch Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Neutral Grain Spirits Flavored',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Whiskey Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Imported Distilled Spirit Specialty',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Special Order Items',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Tennessee Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Canadian Whiskies',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Flavored Vodka',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Cream Liqueurs',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Schnapps',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Triple Sec',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': '100% Agave Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'American Cordials & Liqueur',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  {'Date': '2019-07-02T00:00:00.000',
#   'Category_Name': 'Mixto Tequila',
#   'Volume_Sold_Gallons': 'Volume_Sold (Gallons)'},
#  ...]
